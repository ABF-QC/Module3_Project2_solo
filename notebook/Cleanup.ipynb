# %% [markdown]
# ---
# # Data Cleaning
# ---
#
# ---

# %%
import pandas as pd
import numpy as np

import langid

# %% [markdown]
# ### Read data file

# %%
df = pd.read_csv('../data/games_comments.csv')
df
# Out:
#             username rating  \
# 0     causticforever    NaN
# 1          Corwin007    NaN
# 2        IronTarkles    NaN
# 3             MarkyX    NaN
# 4         mikamikomi    1.0
# ...              ...    ...
# 4165       Aenelruun    8.5
# 4166         Aeremia    6.0
# 4167           Aevey    9.0
# 4168         afafard    7.0
# 4169           Afff3    8.0
#
#                                                 comment max_players  \
# 0     Played prototype- will be an enjoyable way to ...           5
# 1                            UPCOMING\n\nArk Nova lite?           5
# 2                       New game from ark nova designer           5
# 3     I'm very interested in this one. I like the co...           5
# 4          3 artist yet still use stock photos? oh yeah           5
# ...                                                 ...         ...
# 4165                                                 LM           4
# 4166  Cute little game with amazing artwork and nice...           4
# 4167  Only had a few playthroughs so far, but very e...           4
# 4168  Fairly simple and quick engine builder.\nHas a...           4
# 4169  Fun strategy game terraforming mars -esque.\nV...           4
#
#      minplaytime maxplaytime age ratings_avg count_wanting count_wishing
# 0             40         100  12         3.5            44           460
# 1             40         100  12         3.5            44           460
# 2             40         100  12         3.5            44           460
# 3             40         100  12         3.5            44           460
# 4             40         100  12         3.5            44           460
# ...          ...         ...  ..         ...           ...           ...
# 4165          40          80  10     8.00569          1422         21393
# 4166          40          80  10     8.00569          1422         21393
# 4167          40          80  10     8.00569          1422         21393
# 4168          40          80  10     8.00569          1422         21393
# 4169          40          80  10     8.00569          1422         21393
#
# [4170 rows x 10 columns]

# %% [markdown]
# ### Looking for missing values

# %%
df.isna().sum()
# Out:
# username            0
# rating           1338
# comment             7
# max_players         0
# minplaytime         0
# maxplaytime         0
# age                 0
# ratings_avg         0
# count_wanting       0
# count_wishing       0
# dtype: int64

# %% [markdown]
# ### Removing rows without comments

# %%
df = df.dropna(subset=['comment'])

# %%
df.isna().sum()
# Out:
# username            0
# rating           1336
# comment             0
# max_players         0
# minplaytime         0
# maxplaytime         0
# age                 0
# ratings_avg         0
# count_wanting       0
# count_wishing       0
# dtype: int64

# %% [markdown]
# ### Creating a language column

# %%
# Apply language detection
df['lang'] = df['comment'].apply(lambda x: langid.classify(x)[0] if x and len(x.strip()) > 0 else 'unknown')

df[df['lang'] == 'en']
# Out:
# /tmp/ipykernel_436696/173845460.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lang'] = df['comment'].apply(lambda x: x if x.strip() != '' else 'unknown')
# /tmp/ipykernel_436696/173845460.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lang'] = df['comment'].apply(lambda x: langid.classify(x)[0] if x and len(x.strip()) > 0 else 'unknown')
#             username rating  \
# 0     causticforever    NaN
# 1          Corwin007    NaN
# 2        IronTarkles    NaN
# 3             MarkyX    NaN
# 4         mikamikomi    1.0
# ...              ...    ...
# 4165       Aenelruun    8.5
# 4166         Aeremia    6.0
# 4167           Aevey    9.0
# 4168         afafard    7.0
# 4169           Afff3    8.0
#
#                                                 comment max_players  \
# 0     Played prototype- will be an enjoyable way to ...           5
# 1                            UPCOMING\n\nArk Nova lite?           5
# 2                       New game from ark nova designer           5
# 3     I'm very interested in this one. I like the co...           5
# 4          3 artist yet still use stock photos? oh yeah           5
# ...                                                 ...         ...
# 4165                                                 LM           4
# 4166  Cute little game with amazing artwork and nice...           4
# 4167  Only had a few playthroughs so far, but very e...           4
# 4168  Fairly simple and quick engine builder.\nHas a...           4
# 4169  Fun strategy game terraforming mars -esque.\nV...           4
#
#      minplaytime maxplaytime age ratings_avg count_wanting count_wishing lang
# 0             40         100  12         3.5            44           460   en
# 1             40         100  12         3.5            44           460   en
# 2             40         100  12         3.5            44           460   en
# 3             40         100  12         3.5            44           460   en
# 4             40         100  12         3.5            44           460   en
# ...          ...         ...  ..         ...           ...           ...  ...
# 4165          40          80  10     8.00569          1422         21393   en
# 4166          40          80  10     8.00569          1422         21393   en
# 4167          40          80  10     8.00569          1422         21393   en
# 4168          40          80  10     8.00569          1422         21393   en
# 4169          40          80  10     8.00569          1422         21393   en
#
# [3490 rows x 11 columns]

# %% [markdown]
# ---
# ### Write cleaned data file
# ---

# %%
df.to_csv('../data/games_comments_clean.csv', index=False)
