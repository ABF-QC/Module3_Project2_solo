# %% [markdown]
# ---
# # Data Cleaning
# ---
#
# In this notebook we will be cleaning the data file [File](../data/games_comments.csv) .
#
# **Key cleaning steps:**
#   - Removing rows where comments are missing.
#   - Creating a new columns with the language identification of the comment
#
# The results will be store in the data file [Cleaned File](../data/games_comments_clean.csv)
#
# ---

# %% [markdown]
# ### Importing necessary library

# %%
import pandas as pd
import numpy as np

import langid

# %% [markdown]
# ### Read data file

# %%
df = pd.read_csv('../data/games_comments.csv')
df
# Out:
#             username  rating  \
# 0     causticforever     NaN
# 1          Corwin007     NaN
# 2        IronTarkles     NaN
# 3             MarkyX     NaN
# 4         mikamikomi     1.0
# ...              ...     ...
# 4199     chicagometh     4.8
# 4200    Chris Coyote     NaN
# 4201       Chris_P85     9.0
# 4202      Chutch1035     5.0
# 4203         Citadel     NaN
#
#                                                 comment    gamename  \
# 0     Played prototype- will be an enjoyable way to ...   Sanctuary
# 1                            UPCOMING\n\nArk Nova lite?   Sanctuary
# 2                       New game from ark nova designer   Sanctuary
# 3     I'm very interested in this one. I like the co...   Sanctuary
# 4          3 artist yet still use stock photos? oh yeah   Sanctuary
# ...                                                 ...         ...
# 4199  4...'Not so good, but could play again' by BGG...  Civolution
# 4200                                      Birthday 2025  Civolution
# 4201                     Played a half Game at Spiel 24  Civolution
# 4202  I love Feld games and I love Civ games. When I...  Civolution
# 4203  Nice Civ-lite minus the combat element. Tons o...  Civolution
#
#                                               mechanics  min_players  \
# 0     Action Queue,Hand Management,Hexagon Grid,Open...            1
# 1     Action Queue,Hand Management,Hexagon Grid,Open...            1
# 2     Action Queue,Hand Management,Hexagon Grid,Open...            1
# 3     Action Queue,Hand Management,Hexagon Grid,Open...            1
# 4     Action Queue,Hand Management,Hexagon Grid,Open...            1
# ...                                                 ...          ...
# 4199  Area Movement,Dice Rolling,Events,Hand Managem...            1
# 4200  Area Movement,Dice Rolling,Events,Hand Managem...            1
# 4201  Area Movement,Dice Rolling,Events,Hand Managem...            1
# 4202  Area Movement,Dice Rolling,Events,Hand Managem...            1
# 4203  Area Movement,Dice Rolling,Events,Hand Managem...            1
#
#       max_players  minplaytime  maxplaytime  age  ratings_avg  count_wanting  \
# 0               5           40          100   12      7.00000             55
# 1               5           40          100   12      7.00000             55
# 2               5           40          100   12      7.00000             55
# 3               5           40          100   12      7.00000             55
# 4               5           40          100   12      7.00000             55
# ...           ...          ...          ...  ...          ...            ...
# 4199            4           90          180   14      8.21282            580
# 4200            4           90          180   14      8.21282            580
# 4201            4           90          180   14      8.21282            580
# 4202            4           90          180   14      8.21282            580
# 4203            4           90          180   14      8.21282            580
#
#       count_wishing                                        description  \
# 0               569  In Sanctuary, you will plan and design a moder...
# 1               569  In Sanctuary, you will plan and design a moder...
# 2               569  In Sanctuary, you will plan and design a moder...
# 3               569  In Sanctuary, you will plan and design a moder...
# 4               569  In Sanctuary, you will plan and design a moder...
# ...             ...                                                ...
# 4199           4089  Hello, student beings! The cosmic faculty of t...
# 4200           4089  Hello, student beings! The cosmic faculty of t...
# 4201           4089  Hello, student beings! The cosmic faculty of t...
# 4202           4089  Hello, student beings! The cosmic faculty of t...
# 4203           4089  Hello, student beings! The cosmic faculty of t...
#
#                                              categories
# 0              Animals,Environmental,Territory Building
# 1              Animals,Environmental,Territory Building
# 2              Animals,Environmental,Territory Building
# 3              Animals,Environmental,Territory Building
# 4              Animals,Environmental,Territory Building
# ...                                                 ...
# 4199  Civilization,Dice,Economic,Exploration,Science...
# 4200  Civilization,Dice,Economic,Exploration,Science...
# 4201  Civilization,Dice,Economic,Exploration,Science...
# 4202  Civilization,Dice,Economic,Exploration,Science...
# 4203  Civilization,Dice,Economic,Exploration,Science...
#
# [4204 rows x 15 columns]

# %% [markdown]
# ### Looking for missing values

# %%
df.isna().sum()
# Out:
# username            0
# rating           1357
# comment             6
# gamename            0
# mechanics           0
# min_players         0
# max_players         0
# minplaytime         0
# maxplaytime         0
# age                 0
# ratings_avg         0
# count_wanting       0
# count_wishing       0
# description         0
# categories          0
# dtype: int64

# %% [markdown]
# ### Removing rows without comments

# %%
df = df.dropna(subset=['comment'])

# %%
df.isna().sum()
# Out:
# username            0
# rating           1355
# comment             0
# gamename            0
# mechanics           0
# min_players         0
# max_players         0
# minplaytime         0
# maxplaytime         0
# age                 0
# ratings_avg         0
# count_wanting       0
# count_wishing       0
# description         0
# categories          0
# dtype: int64

# %% [markdown]
# ### Creating a language column

# %%
# Apply language detection
df['lang'] = df['comment'].apply(lambda x: langid.classify(x)[0] if x and len(x.strip()) > 0 else 'unknown')

df[df['lang'] == 'en']
# Out:
# /tmp/ipykernel_1868408/1615550910.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lang'] = df['comment'].apply(lambda x: langid.classify(x)[0] if x and len(x.strip()) > 0 else 'unknown')
#             username  rating  \
# 0     causticforever     NaN
# 1          Corwin007     NaN
# 2        IronTarkles     NaN
# 3             MarkyX     NaN
# 4         mikamikomi     1.0
# ...              ...     ...
# 4199     chicagometh     4.8
# 4200    Chris Coyote     NaN
# 4201       Chris_P85     9.0
# 4202      Chutch1035     5.0
# 4203         Citadel     NaN
#
#                                                 comment    gamename  \
# 0     Played prototype- will be an enjoyable way to ...   Sanctuary
# 1                            UPCOMING\n\nArk Nova lite?   Sanctuary
# 2                       New game from ark nova designer   Sanctuary
# 3     I'm very interested in this one. I like the co...   Sanctuary
# 4          3 artist yet still use stock photos? oh yeah   Sanctuary
# ...                                                 ...         ...
# 4199  4...'Not so good, but could play again' by BGG...  Civolution
# 4200                                      Birthday 2025  Civolution
# 4201                     Played a half Game at Spiel 24  Civolution
# 4202  I love Feld games and I love Civ games. When I...  Civolution
# 4203  Nice Civ-lite minus the combat element. Tons o...  Civolution
#
#                                               mechanics  min_players  \
# 0     Action Queue,Hand Management,Hexagon Grid,Open...            1
# 1     Action Queue,Hand Management,Hexagon Grid,Open...            1
# 2     Action Queue,Hand Management,Hexagon Grid,Open...            1
# 3     Action Queue,Hand Management,Hexagon Grid,Open...            1
# 4     Action Queue,Hand Management,Hexagon Grid,Open...            1
# ...                                                 ...          ...
# 4199  Area Movement,Dice Rolling,Events,Hand Managem...            1
# 4200  Area Movement,Dice Rolling,Events,Hand Managem...            1
# 4201  Area Movement,Dice Rolling,Events,Hand Managem...            1
# 4202  Area Movement,Dice Rolling,Events,Hand Managem...            1
# 4203  Area Movement,Dice Rolling,Events,Hand Managem...            1
#
#       max_players  minplaytime  maxplaytime  age  ratings_avg  count_wanting  \
# 0               5           40          100   12      7.00000             55
# 1               5           40          100   12      7.00000             55
# 2               5           40          100   12      7.00000             55
# 3               5           40          100   12      7.00000             55
# 4               5           40          100   12      7.00000             55
# ...           ...          ...          ...  ...          ...            ...
# 4199            4           90          180   14      8.21282            580
# 4200            4           90          180   14      8.21282            580
# 4201            4           90          180   14      8.21282            580
# 4202            4           90          180   14      8.21282            580
# 4203            4           90          180   14      8.21282            580
#
#       count_wishing                                        description  \
# 0               569  In Sanctuary, you will plan and design a moder...
# 1               569  In Sanctuary, you will plan and design a moder...
# 2               569  In Sanctuary, you will plan and design a moder...
# 3               569  In Sanctuary, you will plan and design a moder...
# 4               569  In Sanctuary, you will plan and design a moder...
# ...             ...                                                ...
# 4199           4089  Hello, student beings! The cosmic faculty of t...
# 4200           4089  Hello, student beings! The cosmic faculty of t...
# 4201           4089  Hello, student beings! The cosmic faculty of t...
# 4202           4089  Hello, student beings! The cosmic faculty of t...
# 4203           4089  Hello, student beings! The cosmic faculty of t...
#
#                                              categories lang
# 0              Animals,Environmental,Territory Building   en
# 1              Animals,Environmental,Territory Building   en
# 2              Animals,Environmental,Territory Building   en
# 3              Animals,Environmental,Territory Building   en
# 4              Animals,Environmental,Territory Building   en
# ...                                                 ...  ...
# 4199  Civilization,Dice,Economic,Exploration,Science...   en
# 4200  Civilization,Dice,Economic,Exploration,Science...   en
# 4201  Civilization,Dice,Economic,Exploration,Science...   en
# 4202  Civilization,Dice,Economic,Exploration,Science...   en
# 4203  Civilization,Dice,Economic,Exploration,Science...   en
#
# [3509 rows x 16 columns]

# %%
df['lang'].unique()
# Out:
# array(['en', 'de', 'es', 'nl', 'fr', 'da', 'pl', 'gl', 'hu', 'it', 'oc',
#        'zh', 'no', 'rw', 'ko', 'ja', 'ru', 'ro', 'et', 'sv', 'fi', 'sk',
#        'sl', 'mt', 'ca', 'lt', 'pt', 'uk', 'is', 'eo', 'am', 'cs', 'lv',
#        'bs', 'mg', 'th', 'id', 'be', 'sr', 'ga', 'mn', 'tl', 'tr', 'eu',
#        'nb', 'mk', 'la', 'br', 'ms'], dtype=object)

# %% [markdown]
# ---
# ### Write cleaned data file
# ---

# %%
df.to_csv('../data/games_comments_clean.csv', index=False)
