# %% [markdown]
# ---
# # Data Cleaning
# ---
#
# In this notebook we will be cleaning the data file [File](../data/games_comments.csv) .
#
# **Key cleaning steps:**
#   - Removing rows where comments are missing.
#   - Creating a new columns with the language identification of the comment
#
# The results will be store in the data file [Cleaned File](../data/games_comments_clean.csv)
#
# ---

# %% [markdown]
# ### Importing necessary library

# %%
import pandas as pd
import numpy as np

import langid

# %% [markdown]
# ### Read data file

# %%
df = pd.read_csv('../data/games_comments.csv')
df
# Out:
#             username  rating  \
# 0     causticforever     NaN
# 1          Corwin007     NaN
# 2        IronTarkles     NaN
# 3             MarkyX     NaN
# 4         mikamikomi     1.0
# ...              ...     ...
# 4117       Aenelruun     8.5
# 4118         Aeremia     6.0
# 4119           Aevey     9.0
# 4120         afafard     7.0
# 4121           Afff3     8.0
#
#                                                 comment   gamename  \
# 0     Played prototype- will be an enjoyable way to ...  Sanctuary
# 1                            UPCOMING\n\nArk Nova lite?  Sanctuary
# 2                       New game from ark nova designer  Sanctuary
# 3     I'm very interested in this one. I like the co...  Sanctuary
# 4          3 artist yet still use stock photos? oh yeah  Sanctuary
# ...                                                 ...        ...
# 4117                                                 LM   Everdell
# 4118  Cute little game with amazing artwork and nice...   Everdell
# 4119  Only had a few playthroughs so far, but very e...   Everdell
# 4120  Fairly simple and quick engine builder.\nHas a...   Everdell
# 4121  Fun strategy game terraforming mars -esque.\nV...   Everdell
#
#       max_players  minplaytime  maxplaytime  age  ratings_avg  count_wanting  \
# 0               5           40          100   12      3.50000             44
# 1               5           40          100   12      3.50000             44
# 2               5           40          100   12      3.50000             44
# 3               5           40          100   12      3.50000             44
# 4               5           40          100   12      3.50000             44
# ...           ...          ...          ...  ...          ...            ...
# 4117            4           40           80   10      8.00569           1422
# 4118            4           40           80   10      8.00569           1422
# 4119            4           40           80   10      8.00569           1422
# 4120            4           40           80   10      8.00569           1422
# 4121            4           40           80   10      8.00569           1422
#
#       count_wishing                                        description  \
# 0               460  In Sanctuary, you will plan and design a moder...
# 1               460  In Sanctuary, you will plan and design a moder...
# 2               460  In Sanctuary, you will plan and design a moder...
# 3               460  In Sanctuary, you will plan and design a moder...
# 4               460  In Sanctuary, you will plan and design a moder...
# ...             ...                                                ...
# 4117          21393  Within the charming valley of Everdell, beneat...
# 4118          21393  Within the charming valley of Everdell, beneat...
# 4119          21393  Within the charming valley of Everdell, beneat...
# 4120          21393  Within the charming valley of Everdell, beneat...
# 4121          21393  Within the charming valley of Everdell, beneat...
#
#                                     categories
# 0     Animals,Environmental,Territory Building
# 1     Animals,Environmental,Territory Building
# 2     Animals,Environmental,Territory Building
# 3     Animals,Environmental,Territory Building
# 4     Animals,Environmental,Territory Building
# ...                                        ...
# 4117   Animals,Card Game,City Building,Fantasy
# 4118   Animals,Card Game,City Building,Fantasy
# 4119   Animals,Card Game,City Building,Fantasy
# 4120   Animals,Card Game,City Building,Fantasy
# 4121   Animals,Card Game,City Building,Fantasy
#
# [4122 rows x 13 columns]

# %% [markdown]
# ### Looking for missing values

# %%
df.isna().sum()
# Out:
# username            0
# rating           1338
# comment             7
# gamename            0
# max_players         0
# minplaytime         0
# maxplaytime         0
# age                 0
# ratings_avg         0
# count_wanting       0
# count_wishing       0
# description         0
# categories          0
# dtype: int64

# %% [markdown]
# ### Removing rows without comments

# %%
df = df.dropna(subset=['comment'])

# %%
df.isna().sum()
# Out:
# username            0
# rating           1336
# comment             0
# gamename            0
# max_players         0
# minplaytime         0
# maxplaytime         0
# age                 0
# ratings_avg         0
# count_wanting       0
# count_wishing       0
# description         0
# categories          0
# dtype: int64

# %% [markdown]
# ### Creating a language column

# %%
# Apply language detection
df['lang'] = df['comment'].apply(lambda x: langid.classify(x)[0] if x and len(x.strip()) > 0 else 'unknown')

df[df['lang'] == 'en']
# Out:
# /tmp/ipykernel_985657/1615550910.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lang'] = df['comment'].apply(lambda x: langid.classify(x)[0] if x and len(x.strip()) > 0 else 'unknown')
#             username  rating  \
# 0     causticforever     NaN
# 1          Corwin007     NaN
# 2        IronTarkles     NaN
# 3             MarkyX     NaN
# 4         mikamikomi     1.0
# ...              ...     ...
# 4117       Aenelruun     8.5
# 4118         Aeremia     6.0
# 4119           Aevey     9.0
# 4120         afafard     7.0
# 4121           Afff3     8.0
#
#                                                 comment   gamename  \
# 0     Played prototype- will be an enjoyable way to ...  Sanctuary
# 1                            UPCOMING\n\nArk Nova lite?  Sanctuary
# 2                       New game from ark nova designer  Sanctuary
# 3     I'm very interested in this one. I like the co...  Sanctuary
# 4          3 artist yet still use stock photos? oh yeah  Sanctuary
# ...                                                 ...        ...
# 4117                                                 LM   Everdell
# 4118  Cute little game with amazing artwork and nice...   Everdell
# 4119  Only had a few playthroughs so far, but very e...   Everdell
# 4120  Fairly simple and quick engine builder.\nHas a...   Everdell
# 4121  Fun strategy game terraforming mars -esque.\nV...   Everdell
#
#       max_players  minplaytime  maxplaytime  age  ratings_avg  count_wanting  \
# 0               5           40          100   12      3.50000             44
# 1               5           40          100   12      3.50000             44
# 2               5           40          100   12      3.50000             44
# 3               5           40          100   12      3.50000             44
# 4               5           40          100   12      3.50000             44
# ...           ...          ...          ...  ...          ...            ...
# 4117            4           40           80   10      8.00569           1422
# 4118            4           40           80   10      8.00569           1422
# 4119            4           40           80   10      8.00569           1422
# 4120            4           40           80   10      8.00569           1422
# 4121            4           40           80   10      8.00569           1422
#
#       count_wishing                                        description  \
# 0               460  In Sanctuary, you will plan and design a moder...
# 1               460  In Sanctuary, you will plan and design a moder...
# 2               460  In Sanctuary, you will plan and design a moder...
# 3               460  In Sanctuary, you will plan and design a moder...
# 4               460  In Sanctuary, you will plan and design a moder...
# ...             ...                                                ...
# 4117          21393  Within the charming valley of Everdell, beneat...
# 4118          21393  Within the charming valley of Everdell, beneat...
# 4119          21393  Within the charming valley of Everdell, beneat...
# 4120          21393  Within the charming valley of Everdell, beneat...
# 4121          21393  Within the charming valley of Everdell, beneat...
#
#                                     categories lang
# 0     Animals,Environmental,Territory Building   en
# 1     Animals,Environmental,Territory Building   en
# 2     Animals,Environmental,Territory Building   en
# 3     Animals,Environmental,Territory Building   en
# 4     Animals,Environmental,Territory Building   en
# ...                                        ...  ...
# 4117   Animals,Card Game,City Building,Fantasy   en
# 4118   Animals,Card Game,City Building,Fantasy   en
# 4119   Animals,Card Game,City Building,Fantasy   en
# 4120   Animals,Card Game,City Building,Fantasy   en
# 4121   Animals,Card Game,City Building,Fantasy   en
#
# [3442 rows x 14 columns]

# %%
df['lang'].unique()
# Out:
# array(['en', 'de', 'es', 'nl', 'fr', 'da', 'pl', 'gl', 'hu', 'ko', 'it',
#        'oc', 'zh', 'no', 'et', 'sv', 'ja', 'ru', 'ro', 'fi', 'sk', 'sl',
#        'pt', 'mt', 'ca', 'lt', 'rw', 'uk', 'is', 'eo', 'am', 'cs', 'th',
#        'sr', 'id', 'be', 'ga', 'mg', 'tl', 'mn', 'mk', 'eu', 'ms', 'nb',
#        'tr', 'la', 'br'], dtype=object)

# %% [markdown]
# ---
# ### Write cleaned data file
# ---

# %%
df.to_csv('../data/games_comments_clean.csv', index=False)
